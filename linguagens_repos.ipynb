# %% [markdown]
# ### Conhecendo as requests
# Primeira Requisição:

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a requisição GET

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"46254680658","type":"ReleaseEvent","actor":{"id":6748256,"login":"wso2-jenkins-bot","display_login":"wso2-jenkins-bot","gravatar_id":"","url":"https://api.github.com/users/wso2-jenkins-bot","avatar_url":"https://avatars.githubusercontent.com/u/6748256?"},"repo":{"id":195785625,"name":"wso2/identity-apps","url":"https://api.github.com/repos/wso2/identity-apps"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/wso2/identity-apps/releases/198568081","assets_url":"https://api.github.com/repos/wso2/identity-apps/releases/198568081/assets","upload_url":"https://uploads.github.com/repos/wso2/identity-apps/releases/198568081/assets{?name,label}","html_url":"https://github.com/wso2/identity-apps/releases/tag/%40wso2is/admin.identity-providers.v1%402.26.140","id":198568081,"author":{"login":"wso2-jenkins-bot","id":6748256,"node_id":"MDQ6VXNlcjY3NDgyNTY=","avatar_url":"https://avatars.githubusercontent.com/u/6748256?v=4","gravatar_id":"","url":"https://api.github.com/users/wso2-jenkins-bot","html_url":"https://github.com/wso2-jenkins-bot","followers_url":"https://api.github.com/users/wso2-jenkins-bot/followers","following_url":"https://api.github.com/users/wso2-jenkins-bot/following{/other_user}","gists_url":"https://api.github.com/users/wso2-jenkins-bot/gists{/gist_id}","starred_url":"https://api.github.com/users/wso2-jenkins-bot/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/wso2-jenkins-bot/subscriptions","organizations_url":"https://api.github.com/users/wso2-jenkins-bot/orgs","repos_url":"https://api.github.com/users/wso2-jenkins-bot/repos","events_url":"https://api.github.com/users/wso2-jenkins-bot/events{/privacy}","received_events_url":"https://api.github.com/users/wso2-jenkins-bot/received_events","type":"User","user_view_type":"public","site_admin":false},"node_id":"RE_kwDOC6tzmc4L1eiR","tag_name":"@wso2is/admin.identity-providers.v1@2.26.140","target_commitish":"master","name":"@wso2is/admin.identity-providers.v1@2.26.140","draft":false,"prerelease":false,"created_at":"2025-02-05T12:39:13Z","published_at":"2025-02-05T12:40:59Z","assets":[],"tarball_url":"https://api.github.com/repos/wso2/identity-apps/tarball/@wso2is/admin.identity-providers.v1@2.26.140","zipball_url":"https://api.github.com/repos/wso2/identity-apps/zipball/@wso2is/admin.identity-providers.v1@2.26.140","body":"### Patch Changes\\n\\n-   Updated dependencies \\\\[[`6994a4d6ef9d39263556cb06ece735cd72c96bf5`](https://github.com/wso2/identity-apps/commit/6994a4d6ef9d39263556cb06ece735cd72c96bf5), [`2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df`](https://github.com/wso2/identity-apps/commit/2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df), [`a9231ac6175b28be3d696cb55004cca77191402e`](https://github.com/wso2/identity-apps/commit/a9231ac6175b28be3d696cb55004cca77191402e)]:\\n    -   @wso2is/theme@2.6.6\\n    -   @wso2is/react-components@2.9.4\\n    -   @wso2is/i18n@2.19.3\\n    -   @wso2is/admin.applications.v1@2.30.140\\n    -   @wso2is/admin.extensions.v1@2.36.65\\n    -   @wso2is/admin.claims.v1@2.27.50\\n    -   @wso2is/admin.connections.v1@2.33.23\\n    -   @wso2is/admin.identity-providers.v1@2.26.140\\n    -   @wso2is/admin.organizations.v1@2.26.140\\n    -   @wso2is/admin.roles.v2@2.27.84\\n    -   @wso2is/admin.server-configurations.v1@2.32.65\\n    -   @wso2is/admin.userstores.v1@2.26.99\\n    -   @wso2is/admin.core.v1@2.38.9\\n    -   @wso2is/dynamic-forms@2.4.32\\n    -   @wso2is/form@2.6.25\\n","short_description_html":"<h3>Patch Changes</h3>\\n<ul>\\n<li>Updated dependencies [<a href=\\"https://github.com/wso2/identity-apps/commit/6994a4d6ef9d39263556cb06ece735cd72c96bf5\\"><code>6994a4d6ef9d39263556cb06ece735cd72c96bf5</code></a>, <a href=\\"https://github.com/wso2/identity-apps/commit/2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df\\"><code>2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df</code></a>, <a href=\\"https://github.com/wso2/identity-apps/commit/a9231ac6175b28be3d696cb55004cca77191402e\\"><code>a9231ac617 ...

# %%
r.json()
# Out:
# [{'id': '46254680658',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 6748256,
#    'login': 'wso2-jenkins-bot',
#    'display_login': 'wso2-jenkins-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wso2-jenkins-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6748256?'},
#   'repo': {'id': 195785625,
#    'name': 'wso2/identity-apps',
#    'url': 'https://api.github.com/repos/wso2/identity-apps'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/wso2/identity-apps/releases/198568081',
#     'assets_url': 'https://api.github.com/repos/wso2/identity-apps/releases/198568081/assets',
#     'upload_url': 'https://uploads.github.com/repos/wso2/identity-apps/releases/198568081/assets{?name,label}',
#     'html_url': 'https://github.com/wso2/identity-apps/releases/tag/%40wso2is/admin.identity-providers.v1%402.26.140',
#     'id': 198568081,
#     'author': {'login': 'wso2-jenkins-bot',
#      'id': 6748256,
#      'node_id': 'MDQ6VXNlcjY3NDgyNTY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6748256?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/wso2-jenkins-bot',
#      'html_url': 'https://github.com/wso2-jenkins-bot',
#      'followers_url': 'https://api.github.com/users/wso2-jenkins-bot/followers',
#      'following_url': 'https://api.github.com/users/wso2-jenkins-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/wso2-jenkins-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/wso2-jenkins-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/wso2-jenkins-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/wso2-jenkins-bot/orgs',
#      'repos_url': 'https://api.github.com/users/wso2-jenkins-bot/repos',
#      'events_url': 'https://api.github.com/users/wso2-jenkins-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/wso2-jenkins-bot/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'node_id': 'RE_kwDOC6tzmc4L1eiR',
#     'tag_name': '@wso2is/admin.identity-providers.v1@2.26.140',
#     'target_commitish': 'master',
#     'name': '@wso2is/admin.identity-providers.v1@2.26.140',
#     'draft': False,
#     'prerelease': False,
#     'created_at': '2025-02-05T12:39:13Z',
#     'published_at': '2025-02-05T12:40:59Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/wso2/identity-apps/tarball/@wso2is/admin.identity-providers.v1@2.26.140',
#     'zipball_url': 'https://api.github.com/repos/wso2/identity-apps/zipball/@wso2is/admin.identity-providers.v1@2.26.140',
#     'body': '### Patch Changes\n\n-   Updated dependencies \\[[`6994a4d6ef9d39263556cb06ece735cd72c96bf5`](https://github.com/wso2/identity-apps/commit/6994a4d6ef9d39263556cb06ece735cd72c96bf5), [`2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df`](https://github.com/wso2/identity-apps/commit/2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df), [`a9231ac6175b28be3d696cb55004cca77191402e`](https://github.com/wso2/identity-apps/commit/a9231ac6175b28be3d696cb55004cca77191402e)]:\n    -   @wso2is/theme@2.6.6\n    -   @wso2is/react-components@2.9.4\n    -   @wso2is/i18n@2.19.3\n    -   @wso2is/admin.applications.v1@2.30.140\n    -   @wso2is/admin.extensions.v1@2.36.65\n    -   @wso2is/admin.claims.v1@2.27.50\n    -   @wso2is/admin.connections.v1@2.33.23\n    -   @wso2is/admin.identity-providers.v1@2.26.140\n    -   @wso2is/admin.organizations.v1@2.26.140\n    -   @wso2is/admin.roles.v2@2.27.84\n    -   @wso2is/admin.server-configurations.v1@2.32.65\n    -   @wso2is/admin.userstores.v1@2.26.99\n    -   @wso2is/admin.core.v1@2.38.9\n    -   @wso2is/dynamic-forms@2.4.32\n    -   @wso2is/form@2.6.25\n',
#     'short_description_html': '<h3>Patch Changes</h3>\n<ul>\n<li>Updated dependencies [<a href="https://github.com/wso2/identity-apps/commit/6994a4d6ef9d39263556cb06ece735cd72c96bf5"><code>6994a4d6ef9d39263556cb06ece735cd72c96bf5</code></a>, <a href="https://github.com/wso2/identity-apps/commit/2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df"><code>2c831ff7dc0a263fc0ed20b4599f4a13dd4dc6df</code></a>, <a href="https://github.com/wso2/identity-apps/commit/a9231ac6175b28be3d696cb55004cca77191402e"><code>a9231ac6175b28be3d696cb55004cca77191402e</code></a>]:\n<ul>\n<li>@wso2is/theme@2.6.6</li>\n<li>@wso2is/reac…</li>\n</ul>\n</li>\n</ul>',
#     'is_short_description_html_truncated': True}},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 533043,
#    'login': 'wso2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wso2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/533043?'}},
#  {'id': '46254680651',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 779946008,
#    'name': 'phtea/phtea',
#    'url': 'https://api.github.com/repos/phtea/phtea'},
#   'payload': {'repository_id': 779946008,
#    'push_id': 22490922528,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '022122c9460f30f6b5b8c30e51199bf3d49f9b73',
#    'before': '1f1bd5a781f05f28b9ce50e7f1f83cc63e538306',
#    'commits': [{'sha': '022122c9460f30f6b5b8c30e51199bf3d49f9b73',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update snake animations',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/phtea/phtea/commits/022122c9460f30f6b5b8c30e51199bf3d49f9b73'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680629',
#   'type': 'PushEvent',
#   'actor': {'id': 81254017,
#    'login': 'TomerGrinberg1',
#    'display_login': 'TomerGrinberg1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TomerGrinberg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81254017?'},
#   'repo': {'id': 918110438,
#    'name': 'TomerGrinberg1/dynamic-rechunking-RAG',
#    'url': 'https://api.github.com/repos/TomerGrinberg1/dynamic-rechunking-RAG'},
#   'payload': {'repository_id': 918110438,
#    'push_id': 22490922501,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/tomer-iinitial',
#    'head': 'bee65f1b6df2c60b81e10b10533eacd596392a8c',
#    'before': '6b696a8d674ad196ade769e1d50237be493d0ebc',
#    'commits': [{'sha': '89edb15bc1ac0edfe73cce796f57b7ffcc610fb5',
#      'author': {'email': 'tomerg@copyleaks.com', 'name': 'Tomer Grinberg'},
#      'message': 'bringing the Llama back to life',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TomerGrinberg1/dynamic-rechunking-RAG/commits/89edb15bc1ac0edfe73cce796f57b7ffcc610fb5'},
#     {'sha': 'bee65f1b6df2c60b81e10b10533eacd596392a8c',
#      'author': {'email': 'tomerg@copyleaks.com', 'name': 'Tomer Grinberg'},
#      'message': "Merge branch 'tomer-iinitial' of https://github.com/TomerGrinberg1/dynamic-rechunking-RAG into tomer-iinitial",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TomerGrinberg1/dynamic-rechunking-RAG/commits/bee65f1b6df2c60b81e10b10533eacd596392a8c'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680627',
#   'type': 'PushEvent',
#   'actor': {'id': 1629217,
#    'login': 'codeling',
#    'display_login': 'codeling',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codeling',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1629217?'},
#   'repo': {'id': 60335349,
#    'name': '3dct/open_iA',
#    'url': 'https://api.github.com/repos/3dct/open_iA'},
#   'payload': {'repository_id': 60335349,
#    'push_id': 22490922490,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '3dcd259698adfa50bb9261a3b0b005f1410af8d5',
#    'before': '1878fa7e1d5c1f62472558a8b6d4a4630274b1b0',
#    'commits': [{'sha': '3dcd259698adfa50bb9261a3b0b005f1410af8d5',
#      'author': {'email': 'bernhard.froehler@fh-wels.at',
#       'name': 'Bernhard Froehler'},
#      'message': "github actions: build - re-enable install (trying with removed 'shell: bash')",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3dct/open_iA/commits/3dcd259698adfa50bb9261a3b0b005f1410af8d5'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 16919266,
#    'login': '3dct',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/3dct',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16919266?'}},
#  {'id': '46254680604',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 518273750,
#    'name': 'Albeluiz/Albeluiz',
#    'url': 'https://api.github.com/repos/Albeluiz/Albeluiz'},
#   'payload': {'repository_id': 518273750,
#    'push_id': 22490922495,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'a16559745aab41d00808d6fbd213482038bfe0bf',
#    'before': '4cd8b71a989515905e59417bb258e0e8e3b75962',
#    'commits': [{'sha': 'a16559745aab41d00808d6fbd213482038bfe0bf',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Albeluiz/Albeluiz/commits/a16559745aab41d00808d6fbd213482038bfe0bf'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680550',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 812888164,
#    'name': 'diotoborg/excepturi-deserunt-eaque',
#    'url': 'https://api.github.com/repos/diotoborg/excepturi-deserunt-eaque'},
#   'payload': {'repository_id': 812888164,
#    'push_id': 22490922421,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '85b1b5354a93a3b6c2531b8feceaaf8c5739d4f9',
#    'before': '2f583d33c9bbedaf5260deaa477e20b4300f3152',
#    'commits': [{'sha': '85b1b5354a93a3b6c2531b8feceaaf8c5739d4f9',
#      'author': {'email': '13600593+diotobenijj@users.noreply.github.com',
#       'name': 'diotobenijj'},
#      'message': 'Lupobopelo du feature change lozema mopuwerep nidad library change.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diotoborg/excepturi-deserunt-eaque/commits/85b1b5354a93a3b6c2531b8feceaaf8c5739d4f9'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 167953019,
#    'login': 'diotoborg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/diotoborg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167953019?'}},
#  {'id': '46254680595',
#   'type': 'PushEvent',
#   'actor': {'id': 170480288,
#    'login': 'swa-runner[bot]',
#    'display_login': 'swa-runner',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/170480288?'},
#   'repo': {'id': 927713906,
#    'name': 'mishapos-org/swa512a457526284577ba109f5e604003ac',
#    'url': 'https://api.github.com/repos/mishapos-org/swa512a457526284577ba109f5e604003ac'},
#   'payload': {'repository_id': 927713906,
#    'push_id': 22490922371,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/prBranch',
#    'head': '12fadf613cbb9e0b8539aa7e85be88451c6cbc26',
#    'before': '6ba7524fcb8e89a50bf9e9af8114dc78ba3ee2e9',
#    'commits': [{'sha': '12fadf613cbb9e0b8539aa7e85be88451c6cbc26',
#      'author': {'email': '170480288+swa-runner[bot]@users.noreply.github.com',
#       'name': 'swa-runner[bot]'},
#      'message': 'Writing file api/content.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mishapos-org/swa512a457526284577ba109f5e604003ac/commits/12fadf613cbb9e0b8539aa7e85be88451c6cbc26'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 170479876,
#    'login': 'mishapos-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mishapos-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/170479876?'}},
#  {'id': '46254680601',
#   'type': 'PushEvent',
#   'actor': {'id': 102440059,
#    'login': 'BRENHINES',
#    'display_login': 'BRENHINES',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BRENHINES',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102440059?'},
#   'repo': {'id': 927716533,
#    'name': 'BRENHINES/skills-communicate-using-markdown',
#    'url': 'https://api.github.com/repos/BRENHINES/skills-communicate-using-markdown'},
#   'payload': {'repository_id': 927716533,
#    'push_id': 22490922535,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/start-markdown',
#    'head': '7de532d4aaa2b39d030b7a72961b6cb035c1f4eb',
#    'before': 'd6963d6b99306fbc2c5314d64ad81fddc00d0026',
#    'commits': [{'sha': '7de532d4aaa2b39d030b7a72961b6cb035c1f4eb',
#      'author': {'email': '102440059+BRENHINES@users.noreply.github.com',
#       'name': 'SEREINA YOPA'},
#      'message': 'Update index.md\n\nFEAT: Adding an image in the index.md markdown file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BRENHINES/skills-communicate-using-markdown/commits/7de532d4aaa2b39d030b7a72961b6cb035c1f4eb'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680590',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 867623432,
#    'name': 'xrwt/degisiklik-yapan-sistem',
#    'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem'},
#   'payload': {'repository_id': 867623432,
#    'push_id': 22490922531,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '055f1a9f794ba2207a5e9fdfafa89b36ae4ae38b',
#    'before': '908509730a3ef48bc84d73abe21cea9305b5b845',
#    'commits': [{'sha': '7a9bba2df939d3013da6fec746e9f15704c3c083',
#      'author': {'email': 'xrqu.live@gmail.com', 'name': 'xrwt'},
#      'message': '[➕] Güncelleme (2. Ekleme, 46. Değişiklik)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/7a9bba2df939d3013da6fec746e9f15704c3c083'},
#     {'sha': '055f1a9f794ba2207a5e9fdfafa89b36ae4ae38b',
#      'author': {'email': 'xrqu.live@gmail.com', 'name': 'xrwt'},
#      'message': '[➖] Güncelleme (2. Çıkarma, 46. Değişiklik)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/055f1a9f794ba2207a5e9fdfafa89b36ae4ae38b'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680552',
#   'type': 'PushEvent',
#   'actor': {'id': 4544180,
#    'login': 'roquebetioljr',
#    'display_login': 'roquebetioljr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roquebetioljr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4544180?'},
#   'repo': {'id': 553054629,
#    'name': 'OurPlanscape/Planscape',
#    'url': 'https://api.github.com/repos/OurPlanscape/Planscape'},
#   'payload': {'repository_id': 553054629,
#    'push_id': 22490922532,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bc580bbce8810826fadd809f025a10c73c2eeb8b',
#    'before': '485e1cb97e8209b4606cf780b096061e607950c3',
#    'commits': [{'sha': 'bc580bbce8810826fadd809f025a10c73c2eeb8b',
#      'author': {'email': 'jbetiol@sig-gis.com', 'name': 'Roque Betiol Jr'},
#      'message': 'Impacts E2E test fixes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OurPlanscape/Planscape/commits/bc580bbce8810826fadd809f025a10c73c2eeb8b'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 115884554,
#    'login': 'OurPlanscape',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OurPlanscape',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115884554?'}},
#  {'id': '46254680588',
#   'type': 'CreateEvent',
#   'actor': {'id': 98404186,
#    'login': 'peruccii',
#    'display_login': 'peruccii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peruccii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98404186?'},
#   'repo': {'id': 927721439,
#    'name': 'peruccii/imbl_manutence',
#    'url': 'https://api.github.com/repos/peruccii/imbl_manutence'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680541',
#   'type': 'PushEvent',
#   'actor': {'id': 171124844,
#    'login': 'freeukapp',
#    'display_login': 'freeukapp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freeukapp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/171124844?'},
#   'repo': {'id': 887068329,
#    'name': 'freeukapp/uk',
#    'url': 'https://api.github.com/repos/freeukapp/uk'},
#   'payload': {'repository_id': 887068329,
#    'push_id': 22490922498,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e77a7770961aeb8d3afe4cdafb9ea82f2f61c197',
#    'before': 'd8d42a7a497e0e8abecc204821f2898d2588fcef',
#    'commits': [{'sha': 'e77a7770961aeb8d3afe4cdafb9ea82f2f61c197',
#      'author': {'email': 'appadlou@gmail.com', 'name': 'freeukapp'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freeukapp/uk/commits/e77a7770961aeb8d3afe4cdafb9ea82f2f61c197'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680558',
#   'type': 'PushEvent',
#   'actor': {'id': 105532932,
#    'login': 'gxusb',
#    'display_login': 'gxusb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gxusb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105532932?'},
#   'repo': {'id': 492113349,
#    'name': 'gxusb/gxusb',
#    'url': 'https://api.github.com/repos/gxusb/gxusb'},
#   'payload': {'repository_id': 492113349,
#    'push_id': 22490922446,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'e4ce2a072c1c7a0dcfc1b4812c32d8067957ccb2',
#    'before': '59cdb2239c9ae7a70fd14487f5185d5af70d58fe',
#    'commits': [{'sha': 'e4ce2a072c1c7a0dcfc1b4812c32d8067957ccb2',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gxusb/gxusb/commits/e4ce2a072c1c7a0dcfc1b4812c32d8067957ccb2'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680582',
#   'type': 'CreateEvent',
#   'actor': {'id': 151583193,
#    'login': 'BlankTMing',
#    'display_login': 'BlankTMing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BlankTMing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151583193?'},
#   'repo': {'id': 731609326,
#    'name': 'BlankTMing/ManifestAutoUpdate',
#    'url': 'https://api.github.com/repos/BlankTMing/ManifestAutoUpdate'},
#   'payload': {'ref': '1808682_8511287023071455693',
#    'ref_type': 'tag',
#    'master_branch': '001000001000',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680574',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 79500257,
#    'login': 'Rakshithb1',
#    'display_login': 'Rakshithb1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rakshithb1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79500257?'},
#   'repo': {'id': 233785512,
#    'name': 'mosip/commons',
#    'url': 'https://api.github.com/repos/mosip/commons'},
#   'payload': {'action': 'opened',
#    'number': 1603,
#    'pull_request': {'url': 'https://api.github.com/repos/mosip/commons/pulls/1603',
#     'id': 2317526674,
#     'node_id': 'PR_kwDODe9IqM6KIqaS',
#     'html_url': 'https://github.com/mosip/commons/pull/1603',
#     'diff_url': 'https://github.com/mosip/commons/pull/1603.diff',
#     'patch_url': 'https://github.com/mosip/commons/pull/1603.patch',
#     'issue_url': 'https://api.github.com/repos/mosip/commons/issues/1603',
#     'number': 1603,
#     'state': 'open',
#     'locked': False,
#     'title': '[MOSIP-35637] added sqaush layers',
#     'user': {'login': 'Rakshithb1',
#      'id': 79500257,
#      'node_id': 'MDQ6VXNlcjc5NTAwMjU3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/79500257?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Rakshithb1',
#      'html_url': 'https://github.com/Rakshithb1',
#      'followers_url': 'https://api.github.com/users/Rakshithb1/followers',
#      'following_url': 'https://api.github.com/users/Rakshithb1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Rakshithb1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Rakshithb1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Rakshithb1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Rakshithb1/orgs',
#      'repos_url': 'https://api.github.com/users/Rakshithb1/repos',
#      'events_url': 'https://api.github.com/users/Rakshithb1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Rakshithb1/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2025-02-05T12:40:57Z',
#     'updated_at': '2025-02-05T12:40:57Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mosip/commons/pulls/1603/commits',
#     'review_comments_url': 'https://api.github.com/repos/mosip/commons/pulls/1603/comments',
#     'review_comment_url': 'https://api.github.com/repos/mosip/commons/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mosip/commons/issues/1603/comments',
#     'statuses_url': 'https://api.github.com/repos/mosip/commons/statuses/4efc20b7a27a4477c3b416f3292d26985ad9aee6',
#     'head': {'label': 'Rakshithb1:develop',
#      'ref': 'develop',
#      'sha': '4efc20b7a27a4477c3b416f3292d26985ad9aee6',
#      'user': {'login': 'Rakshithb1',
#       'id': 79500257,
#       'node_id': 'MDQ6VXNlcjc5NTAwMjU3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/79500257?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Rakshithb1',
#       'html_url': 'https://github.com/Rakshithb1',
#       'followers_url': 'https://api.github.com/users/Rakshithb1/followers',
#       'following_url': 'https://api.github.com/users/Rakshithb1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Rakshithb1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Rakshithb1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Rakshithb1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Rakshithb1/orgs',
#       'repos_url': 'https://api.github.com/users/Rakshithb1/repos',
#       'events_url': 'https://api.github.com/users/Rakshithb1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Rakshithb1/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 870051457,
#       'node_id': 'R_kgDOM9vugQ',
#       'name': 'commons',
#       'full_name': 'Rakshithb1/commons',
#       'private': False,
#       'owner': {'login': 'Rakshithb1',
#        'id': 79500257,
#        'node_id': 'MDQ6VXNlcjc5NTAwMjU3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/79500257?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Rakshithb1',
#        'html_url': 'https://github.com/Rakshithb1',
#        'followers_url': 'https://api.github.com/users/Rakshithb1/followers',
#        'following_url': 'https://api.github.com/users/Rakshithb1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Rakshithb1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Rakshithb1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Rakshithb1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Rakshithb1/orgs',
#        'repos_url': 'https://api.github.com/users/Rakshithb1/repos',
#        'events_url': 'https://api.github.com/users/Rakshithb1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Rakshithb1/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Rakshithb1/commons',
#       'description': 'This repository contains common utilities and services used by other MOSIP modules',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Rakshithb1/commons',
#       'forks_url': 'https://api.github.com/repos/Rakshithb1/commons/forks',
#       'keys_url': 'https://api.github.com/repos/Rakshithb1/commons/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Rakshithb1/commons/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Rakshithb1/commons/teams',
#       'hooks_url': 'https://api.github.com/repos/Rakshithb1/commons/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Rakshithb1/commons/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Rakshithb1/commons/events',
#       'assignees_url': 'https://api.github.com/repos/Rakshithb1/commons/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Rakshithb1/commons/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Rakshithb1/commons/tags',
#       'blobs_url': 'https://api.github.com/repos/Rakshithb1/commons/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Rakshithb1/commons/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Rakshithb1/commons/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Rakshithb1/commons/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Rakshithb1/commons/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Rakshithb1/commons/languages',
#       'stargazers_url': 'https://api.github.com/repos/Rakshithb1/commons/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Rakshithb1/commons/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Rakshithb1/commons/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Rakshithb1/commons/subscription',
#       'commits_url': 'https://api.github.com/repos/Rakshithb1/commons/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Rakshithb1/commons/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Rakshithb1/commons/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Rakshithb1/commons/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Rakshithb1/commons/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Rakshithb1/commons/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Rakshithb1/commons/merges',
#       'archive_url': 'https://api.github.com/repos/Rakshithb1/commons/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Rakshithb1/commons/downloads',
#       'issues_url': 'https://api.github.com/repos/Rakshithb1/commons/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Rakshithb1/commons/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Rakshithb1/commons/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Rakshithb1/commons/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Rakshithb1/commons/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Rakshithb1/commons/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Rakshithb1/commons/deployments',
#       'created_at': '2024-10-09T11:04:13Z',
#       'updated_at': '2024-10-09T11:04:13Z',
#       'pushed_at': '2025-02-05T12:40:34Z',
#       'git_url': 'git://github.com/Rakshithb1/commons.git',
#       'ssh_url': 'git@github.com:Rakshithb1/commons.git',
#       'clone_url': 'https://github.com/Rakshithb1/commons.git',
#       'svn_url': 'https://github.com/Rakshithb1/commons',
#       'homepage': None,
#       'size': 216575,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mpl-2.0',
#        'name': 'Mozilla Public License 2.0',
#        'spdx_id': 'MPL-2.0',
#        'url': 'https://api.github.com/licenses/mpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTE0'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': True,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'mosip:develop',
#      'ref': 'develop',
#      'sha': '3080af32cc9a6f17c8fd8c7e02c608ce05f4bf8a',
#      'user': {'login': 'mosip',
#       'id': 39733477,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5NzMzNDc3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/39733477?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mosip',
#       'html_url': 'https://github.com/mosip',
#       'followers_url': 'https://api.github.com/users/mosip/followers',
#       'following_url': 'https://api.github.com/users/mosip/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mosip/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mosip/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mosip/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mosip/orgs',
#       'repos_url': 'https://api.github.com/users/mosip/repos',
#       'events_url': 'https://api.github.com/users/mosip/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mosip/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 233785512,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzM3ODU1MTI=',
#       'name': 'commons',
#       'full_name': 'mosip/commons',
#       'private': False,
#       'owner': {'login': 'mosip',
#        'id': 39733477,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM5NzMzNDc3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/39733477?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mosip',
#        'html_url': 'https://github.com/mosip',
#        'followers_url': 'https://api.github.com/users/mosip/followers',
#        'following_url': 'https://api.github.com/users/mosip/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mosip/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mosip/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mosip/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mosip/orgs',
#        'repos_url': 'https://api.github.com/users/mosip/repos',
#        'events_url': 'https://api.github.com/users/mosip/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mosip/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/mosip/commons',
#       'description': 'This repository contains common utilities and services used by other MOSIP modules',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mosip/commons',
#       'forks_url': 'https://api.github.com/repos/mosip/commons/forks',
#       'keys_url': 'https://api.github.com/repos/mosip/commons/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mosip/commons/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mosip/commons/teams',
#       'hooks_url': 'https://api.github.com/repos/mosip/commons/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mosip/commons/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mosip/commons/events',
#       'assignees_url': 'https://api.github.com/repos/mosip/commons/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mosip/commons/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mosip/commons/tags',
#       'blobs_url': 'https://api.github.com/repos/mosip/commons/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mosip/commons/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mosip/commons/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mosip/commons/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mosip/commons/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mosip/commons/languages',
#       'stargazers_url': 'https://api.github.com/repos/mosip/commons/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mosip/commons/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mosip/commons/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mosip/commons/subscription',
#       'commits_url': 'https://api.github.com/repos/mosip/commons/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mosip/commons/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mosip/commons/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mosip/commons/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mosip/commons/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mosip/commons/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mosip/commons/merges',
#       'archive_url': 'https://api.github.com/repos/mosip/commons/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mosip/commons/downloads',
#       'issues_url': 'https://api.github.com/repos/mosip/commons/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mosip/commons/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mosip/commons/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mosip/commons/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mosip/commons/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mosip/commons/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mosip/commons/deployments',
#       'created_at': '2020-01-14T07:45:35Z',
#       'updated_at': '2025-02-03T18:42:36Z',
#       'pushed_at': '2025-02-05T05:35:05Z',
#       'git_url': 'git://github.com/mosip/commons.git',
#       'ssh_url': 'git@github.com:mosip/commons.git',
#       'clone_url': 'https://github.com/mosip/commons.git',
#       'svn_url': 'https://github.com/mosip/commons',
#       'homepage': None,
#       'size': 216586,
#       'stargazers_count': 15,
#       'watchers_count': 15,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 181,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 41,
#       'license': {'key': 'mpl-2.0',
#        'name': 'Mozilla Public License 2.0',
#        'spdx_id': 'MPL-2.0',
#        'url': 'https://api.github.com/licenses/mpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTE0'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': True,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 181,
#       'open_issues': 41,
#       'watchers': 15,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mosip/commons/pulls/1603'},
#      'html': {'href': 'https://github.com/mosip/commons/pull/1603'},
#      'issue': {'href': 'https://api.github.com/repos/mosip/commons/issues/1603'},
#      'comments': {'href': 'https://api.github.com/repos/mosip/commons/issues/1603/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mosip/commons/pulls/1603/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mosip/commons/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mosip/commons/pulls/1603/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mosip/commons/statuses/4efc20b7a27a4477c3b416f3292d26985ad9aee6'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 39733477,
#    'login': 'mosip',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mosip',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39733477?'}},
#  {'id': '46254680562',
#   'type': 'CreateEvent',
#   'actor': {'id': 128239984,
#    'login': 'Juanje24',
#    'display_login': 'Juanje24',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Juanje24',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128239984?'},
#   'repo': {'id': 927721436,
#    'name': 'Juanje24/AED1',
#    'url': 'https://api.github.com/repos/Juanje24/AED1'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Repositorio con la práctica desarrollada en C++ para la asignatura de Algoritmos y Estructuras de Datos I',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680532',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 805384180,
#    'name': 'thien1103/thien1103',
#    'url': 'https://api.github.com/repos/thien1103/thien1103'},
#   'payload': {'repository_id': 805384180,
#    'push_id': 22490922415,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '076804ea91c78c14f3aab40f01b12c0d170b94d1',
#    'before': '53bdf66e4fbf86d5ec24c60154ffb941b9b3f5c9',
#    'commits': [{'sha': '076804ea91c78c14f3aab40f01b12c0d170b94d1',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update snake animations',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thien1103/thien1103/commits/076804ea91c78c14f3aab40f01b12c0d170b94d1'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680530',
#   'type': 'PushEvent',
#   'actor': {'id': 58255472,
#    'login': 'zacw-243L',
#    'display_login': 'zacw-243L',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zacw-243L',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58255472?'},
#   'repo': {'id': 916397814,
#    'name': 'zacw-243L/How-to-inflate-your-commits-',
#    'url': 'https://api.github.com/repos/zacw-243L/How-to-inflate-your-commits-'},
#   'payload': {'repository_id': 916397814,
#    'push_id': 22490922367,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a711fe4b758bd6c723f6a06cef3fc915e20796be',
#    'before': '8bb6e1242df8581781e940f3ea620b9883ebedfd',
#    'commits': [{'sha': 'a711fe4b758bd6c723f6a06cef3fc915e20796be',
#      'author': {'email': 'qwerty.amousy123442x@gmail.com',
#       'name': 'zacw-243L'},
#      'message': 'Update made at Wed 05/02/2025 20:40:54.34',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zacw-243L/How-to-inflate-your-commits-/commits/a711fe4b758bd6c723f6a06cef3fc915e20796be'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680504',
#   'type': 'PushEvent',
#   'actor': {'id': 106121522,
#    'login': 'codingbart',
#    'display_login': 'codingbart',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codingbart',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106121522?'},
#   'repo': {'id': 903565995,
#    'name': 'codingbart/english_learning_app',
#    'url': 'https://api.github.com/repos/codingbart/english_learning_app'},
#   'payload': {'repository_id': 903565995,
#    'push_id': 22490922451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b5b2bc659f7c39736c4be1ac24a3f439f882d8c1',
#    'before': '4f28bb434d19cb81034ffc3b0a276c0b7d394a08',
#    'commits': [{'sha': 'b5b2bc659f7c39736c4be1ac24a3f439f882d8c1',
#      'author': {'email': 'bkarkoszka@wp.pl', 'name': 'Bartek Karkoszka'},
#      'message': 'updated textinput',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/codingbart/english_learning_app/commits/b5b2bc659f7c39736c4be1ac24a3f439f882d8c1'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680524',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 30189103,
#    'login': 'openshift-ci-robot',
#    'display_login': 'openshift-ci-robot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openshift-ci-robot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30189103?'},
#   'repo': {'id': 372849086,
#    'name': 'red-hat-storage/odf-operator',
#    'url': 'https://api.github.com/repos/red-hat-storage/odf-operator'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525',
#     'repository_url': 'https://api.github.com/repos/red-hat-storage/odf-operator',
#     'labels_url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525/comments',
#     'events_url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525/events',
#     'html_url': 'https://github.com/red-hat-storage/odf-operator/pull/525',
#     'id': 2832671962,
#     'node_id': 'PR_kwDOFjk5vs6KIEcK',
#     'number': 525,
#     'title': 'DFBUGS-268:godeps: update go-retryablehttp to v0.7.7 (fix CVE-2024-6104)',
#     'user': {'login': 'iamniting',
#      'id': 22993933,
#      'node_id': 'MDQ6VXNlcjIyOTkzOTMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/22993933?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/iamniting',
#      'html_url': 'https://github.com/iamniting',
#      'followers_url': 'https://api.github.com/users/iamniting/followers',
#      'following_url': 'https://api.github.com/users/iamniting/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/iamniting/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/iamniting/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/iamniting/subscriptions',
#      'organizations_url': 'https://api.github.com/users/iamniting/orgs',
#      'repos_url': 'https://api.github.com/users/iamniting/repos',
#      'events_url': 'https://api.github.com/users/iamniting/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/iamniting/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 3214664914,
#       'node_id': 'MDU6TGFiZWwzMjE0NjY0OTE0',
#       'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/labels/approved',
#       'name': 'approved',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates a PR has been approved by an approver from all required OWNERS files.'},
#      {'id': 7768538820,
#       'node_id': 'LA_kwDOFjk5vs8AAAABzwp-xA',
#       'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/labels/jira/invalid-bug',
#       'name': 'jira/invalid-bug',
#       'color': 'e11d21',
#       'default': False,
#       'description': 'Indicates that the referenced jira bug is invalid for the branch this PR is targeting'},
#      {'id': 7768902261,
#       'node_id': 'LA_kwDOFjk5vs8AAAABzxAKdQ',
#       'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/labels/jira/valid-reference',
#       'name': 'jira/valid-reference',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates that this PR references a valid jira ticket of any type'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2025-02-05T11:29:30Z',
#     'updated_at': '2025-02-05T12:40:59Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/pulls/525',
#      'html_url': 'https://github.com/red-hat-storage/odf-operator/pull/525',
#      'diff_url': 'https://github.com/red-hat-storage/odf-operator/pull/525.diff',
#      'patch_url': 'https://github.com/red-hat-storage/odf-operator/pull/525.patch',
#      'merged_at': None},
#     'body': 'Signed-off-by: Nitin Goyal <nigoyal@redhat.com>\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/comments/2636685206',
#     'html_url': 'https://github.com/red-hat-storage/odf-operator/pull/525#issuecomment-2636685206',
#     'issue_url': 'https://api.github.com/repos/red-hat-storage/odf-operator/issues/525',
#     'id': 2636685206,
#     'node_id': 'IC_kwDOFjk5vs6dKJ-W',
#     'user': {'login': 'openshift-ci-robot',
#      'id': 30189103,
#      'node_id': 'MDQ6VXNlcjMwMTg5MTAz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30189103?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/openshift-ci-robot',
#      'html_url': 'https://github.com/openshift-ci-robot',
#      'followers_url': 'https://api.github.com/users/openshift-ci-robot/followers',
#      'following_url': 'https://api.github.com/users/openshift-ci-robot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/openshift-ci-robot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/openshift-ci-robot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/openshift-ci-robot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/openshift-ci-robot/orgs',
#      'repos_url': 'https://api.github.com/users/openshift-ci-robot/repos',
#      'events_url': 'https://api.github.com/users/openshift-ci-robot/events{/privacy}',
# ...
#        'id': 6254131,
#        'node_id': 'MDQ6VXNlcjYyNTQxMzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6254131?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/corsicanu',
#        'html_url': 'https://github.com/corsicanu',
#        'followers_url': 'https://api.github.com/users/corsicanu/followers',
#        'following_url': 'https://api.github.com/users/corsicanu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/corsicanu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/corsicanu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/corsicanu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/corsicanu/orgs',
#        'repos_url': 'https://api.github.com/users/corsicanu/repos',
#        'events_url': 'https://api.github.com/users/corsicanu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/corsicanu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 37582764,
#       'download_count': 0,
#       'created_at': '2025-02-05T12:40:49Z',
#       'updated_at': '2025-02-05T12:40:50Z',
#       'browser_download_url': 'https://github.com/corsicanu/goodlock_dump/releases/download/34/com.samsung.android.themedesigner.apk'},
#      {'url': 'https://api.github.com/repos/corsicanu/goodlock_dump/releases/assets/226497736',
#       'id': 226497736,
#       'node_id': 'RA_kwDOKPeFi84NgBTI',
#       'name': 'com.samsung.android.wonderland.wallpaper.apk',
#       'label': '',
#       'uploader': {'login': 'corsicanu',
#        'id': 6254131,
#        'node_id': 'MDQ6VXNlcjYyNTQxMzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6254131?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/corsicanu',
#        'html_url': 'https://github.com/corsicanu',
#        'followers_url': 'https://api.github.com/users/corsicanu/followers',
#        'following_url': 'https://api.github.com/users/corsicanu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/corsicanu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/corsicanu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/corsicanu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/corsicanu/orgs',
#        'repos_url': 'https://api.github.com/users/corsicanu/repos',
#        'events_url': 'https://api.github.com/users/corsicanu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/corsicanu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 87512290,
#       'download_count': 0,
#       'created_at': '2025-02-05T12:40:51Z',
#       'updated_at': '2025-02-05T12:40:53Z',
#       'browser_download_url': 'https://github.com/corsicanu/goodlock_dump/releases/download/34/com.samsung.android.wonderland.wallpaper.apk'},
#      {'url': 'https://api.github.com/repos/corsicanu/goodlock_dump/releases/assets/226497749',
#       'id': 226497749,
#       'node_id': 'RA_kwDOKPeFi84NgBTV',
#       'name': 'com.samsung.systemui.lockstar.apk',
#       'label': '',
#       'uploader': {'login': 'corsicanu',
#        'id': 6254131,
#        'node_id': 'MDQ6VXNlcjYyNTQxMzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6254131?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/corsicanu',
#        'html_url': 'https://github.com/corsicanu',
#        'followers_url': 'https://api.github.com/users/corsicanu/followers',
#        'following_url': 'https://api.github.com/users/corsicanu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/corsicanu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/corsicanu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/corsicanu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/corsicanu/orgs',
#        'repos_url': 'https://api.github.com/users/corsicanu/repos',
#        'events_url': 'https://api.github.com/users/corsicanu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/corsicanu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 68767536,
#       'download_count': 0,
#       'created_at': '2025-02-05T12:40:54Z',
#       'updated_at': '2025-02-05T12:40:56Z',
#       'browser_download_url': 'https://github.com/corsicanu/goodlock_dump/releases/download/34/com.samsung.systemui.lockstar.apk'},
#      {'url': 'https://api.github.com/repos/corsicanu/goodlock_dump/releases/assets/226497762',
#       'id': 226497762,
#       'node_id': 'RA_kwDOKPeFi84NgBTi',
#       'name': 'com.samsung.systemui.navillera.apk',
#       'label': '',
#       'uploader': {'login': 'corsicanu',
#        'id': 6254131,
#        'node_id': 'MDQ6VXNlcjYyNTQxMzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6254131?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/corsicanu',
#        'html_url': 'https://github.com/corsicanu',
#        'followers_url': 'https://api.github.com/users/corsicanu/followers',
#        'following_url': 'https://api.github.com/users/corsicanu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/corsicanu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/corsicanu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/corsicanu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/corsicanu/orgs',
#        'repos_url': 'https://api.github.com/users/corsicanu/repos',
#        'events_url': 'https://api.github.com/users/corsicanu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/corsicanu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 15047683,
#       'download_count': 0,
#       'created_at': '2025-02-05T12:40:56Z',
#       'updated_at': '2025-02-05T12:40:57Z',
#       'browser_download_url': 'https://github.com/corsicanu/goodlock_dump/releases/download/34/com.samsung.systemui.navillera.apk'},
#      {'url': 'https://api.github.com/repos/corsicanu/goodlock_dump/releases/assets/226497770',
#       'id': 226497770,
#       'node_id': 'RA_kwDOKPeFi84NgBTq',
#       'name': 'com.samsung.systemui.notilus.apk',
#       'label': '',
#       'uploader': {'login': 'corsicanu',
#        'id': 6254131,
#        'node_id': 'MDQ6VXNlcjYyNTQxMzE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6254131?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/corsicanu',
#        'html_url': 'https://github.com/corsicanu',
#        'followers_url': 'https://api.github.com/users/corsicanu/followers',
#        'following_url': 'https://api.github.com/users/corsicanu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/corsicanu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/corsicanu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/corsicanu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/corsicanu/orgs',
#        'repos_url': 'https://api.github.com/users/corsicanu/repos',
#        'events_url': 'https://api.github.com/users/corsicanu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/corsicanu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'content_type': 'application/vnd.android.package-archive',
#       'state': 'uploaded',
#       'size': 10373060,
#       'download_count': 0,
#       'created_at': '2025-02-05T12:40:57Z',
#       'updated_at': '2025-02-05T12:40:58Z',
#       'browser_download_url': 'https://github.com/corsicanu/goodlock_dump/releases/download/34/com.samsung.systemui.notilus.apk'}],
#     'tarball_url': 'https://api.github.com/repos/corsicanu/goodlock_dump/tarball/34',
#     'zipball_url': 'https://api.github.com/repos/corsicanu/goodlock_dump/zipball/34',
#     'body': 'Included apps and versions: \n- Camera Assistant 2.1.00.2 \n- ClockFace 3.1.07.0 \n- Edge lighting+ 6.1.00.6 \n- EdgeTouch 1.2.29 \n- Home Up 15.0.01.19 \n- Keys Cafe 1.6.01.11 \n- LockStar 6.1.00.18 \n- MultiStar 7.2.19 \n- NavStar 6.1.05.33 \n- Nice Catch 7.0.00.0 \n- Nice Shot 2.2.01 \n- NotiStar 7.0.15.0 \n- One Hand Operation + 7.3.19.0 \n- Pentastic 2.2.04 \n- QuickStar 7.4.07.56 \n- RegiStar 1.0.54 \n- Routines + 1.0.60 \n- Sound Assistant 6.1.00.9 \n- Theme Park 1.1.01.5 \n- Wonderland 1.6.06 ',
#     'short_description_html': '<p>Included apps and versions:</p>\n<ul>\n<li>Camera Assistant 2.1.00.2</li>\n<li>ClockFace 3.1.07.0</li>\n<li>Edge lighting+ 6.1.00.6</li>\n<li>EdgeTouch 1.2.29</li>\n<li>Home Up 15.0.01.19</li>\n<li>Keys Cafe 1.6.01.11</li>\n<li>LockStar 6.1.00.18</li>\n<li>MultiStar 7.2.19</li>\n<li>NavStar…</li>\n</ul>',
#     'is_short_description_html_truncated': True}},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680518',
#   'type': 'WatchEvent',
#   'actor': {'id': 4939600,
#    'login': 'ckhawks',
#    'display_login': 'ckhawks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ckhawks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4939600?'},
#   'repo': {'id': 431215894,
#    'name': 'Dsiman/Kronos',
#    'url': 'https://api.github.com/repos/Dsiman/Kronos'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680462',
#   'type': 'PushEvent',
#   'actor': {'id': 2405279,
#    'login': 'zerai',
#    'display_login': 'zerai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zerai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2405279?'},
#   'repo': {'id': 697239395,
#    'name': 'MedicalMundi/marketplace-engine',
#    'url': 'https://api.github.com/repos/MedicalMundi/marketplace-engine'},
#   'payload': {'repository_id': 697239395,
#    'push_id': 22490922428,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '448676770e63694fadd5febb38cecba30dad17dd',
#    'before': '9b2c62ccaaf3cc756625b039d4da2e9e984935bd',
#    'commits': [{'sha': '583fbdeea74c765f02f1a9271fe1512f93b7da23',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'composer(deps-dev): bump zenstruck/foundry from 2.3.1 to 2.3.3\n\nBumps [zenstruck/foundry](https://github.com/zenstruck/foundry) from 2.3.1 to 2.3.3.\n- [Release notes](https://github.com/zenstruck/foundry/releases)\n- [Changelog](https://github.com/zenstruck/foundry/blob/2.x/CHANGELOG.md)\n- [Commits](https://github.com/zenstruck/foundry/compare/v2.3.1...v2.3.3)\n\n---\nupdated-dependencies:\n- dependency-name: zenstruck/foundry\n  dependency-type: direct:development\n  update-type: version-update:semver-patch\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/MedicalMundi/marketplace-engine/commits/583fbdeea74c765f02f1a9271fe1512f93b7da23'},
#     {'sha': '448676770e63694fadd5febb38cecba30dad17dd',
#      'author': {'email': 'teclaizerai@gmail.com', 'name': 'zero'},
#      'message': 'Merge pull request #274 from MedicalMundi/dependabot/composer/main/zenstruck/foundry-2.3.3\n\ncomposer(deps-dev): bump zenstruck/foundry from 2.3.1 to 2.3.3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MedicalMundi/marketplace-engine/commits/448676770e63694fadd5febb38cecba30dad17dd'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z',
#   'org': {'id': 58269871,
#    'login': 'MedicalMundi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MedicalMundi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58269871?'}},
#  {'id': '46254680480',
#   'type': 'PushEvent',
#   'actor': {'id': 21219669,
#    'login': 'vedantthete',
#    'display_login': 'vedantthete',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vedantthete',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21219669?'},
#   'repo': {'id': 842248313,
#    'name': 'vedantthete/google-drive-torrent',
#    'url': 'https://api.github.com/repos/vedantthete/google-drive-torrent'},
#   'payload': {'repository_id': 842248313,
#    'push_id': 22490922370,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/public',
#    'head': '0d6ca93f14ad27d3b7a828b5b9775a1ff0878270',
#    'before': '16e0f73ff3d92dfa0b267ed9bc44da051949c003',
#    'commits': [{'sha': '0d6ca93f14ad27d3b7a828b5b9775a1ff0878270',
#      'author': {'email': 'vedantthete@gmail.com', 'name': 'vedantthete'},
#      'message': '',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vedantthete/google-drive-torrent/commits/0d6ca93f14ad27d3b7a828b5b9775a1ff0878270'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680490',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 922861838,
#    'name': 'Yiwenjia1/Yiwenjia1',
#    'url': 'https://api.github.com/repos/Yiwenjia1/Yiwenjia1'},
#   'payload': {'repository_id': 922861838,
#    'push_id': 22490922442,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '8dfc847790ad2e780923be3e2f775ed8dca628a4',
#    'before': 'fbfa80b435364d3b7322d1596a47c5adde229c01',
#    'commits': [{'sha': '8dfc847790ad2e780923be3e2f775ed8dca628a4',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Yiwenjia1/Yiwenjia1/commits/8dfc847790ad2e780923be3e2f775ed8dca628a4'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'},
#  {'id': '46254680458',
#   'type': 'PushEvent',
#   'actor': {'id': 186038663,
#    'login': 'Bianchi-Emanuele',
#    'display_login': 'Bianchi-Emanuele',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bianchi-Emanuele',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/186038663?'},
#   'repo': {'id': 884199560,
#    'name': 'Bianchi-Emanuele/3INFO_2425',
#    'url': 'https://api.github.com/repos/Bianchi-Emanuele/3INFO_2425'},
#   'payload': {'repository_id': 884199560,
#    'push_id': 22490922366,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/esercizi-TPSI',
#    'head': '2efa6a99bf65882f63b6e664e2df008414f021bd',
#    'before': '577adc7d4c609cd157d25443b70f3cc854249b1f',
#    'commits': [{'sha': '8e1fc332f8336ce9e2511a3e0ca90d7a96e06993',
#      'author': {'email': 'emanuele.bianchi@istitutoagnelli.it',
#       'name': 'Bianchi-Emanuele'},
#      'message': 'Esercitazione 1, 2, 3, 4,5, 6 CSS\n\nesercitazioni CSS',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Bianchi-Emanuele/3INFO_2425/commits/8e1fc332f8336ce9e2511a3e0ca90d7a96e06993'},
#     {'sha': '2efa6a99bf65882f63b6e664e2df008414f021bd',
#      'author': {'email': 'emanuele.bianchi@istitutoagnelli.it',
#       'name': 'Bianchi-Emanuele'},
#      'message': 'Merge pull request #1 from Bianchi-Emanuele/main\n\nEsercitazione 1, 2, 3, 4,5, 6 CSS',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Bianchi-Emanuele/3INFO_2425/commits/2efa6a99bf65882f63b6e664e2df008414f021bd'}]},
#   'public': True,
#   'created_at': '2025-02-05T12:40:59Z'}]

# %%
r = requests.get('https://api.github.com/versions')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']
