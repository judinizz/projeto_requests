# %% [markdown]
# ### Conhecendo as requests
# Primeira Requisição:

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a requisição GET

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"46306376622","type":"WatchEvent","actor":{"id":81527587,"login":"denizkarhan","display_login":"denizkarhan","gravatar_id":"","url":"https://api.github.com/users/denizkarhan","avatar_url":"https://avatars.githubusercontent.com/u/81527587?"},"repo":{"id":926978798,"name":"kyutai-labs/hibiki","url":"https://api.github.com/repos/kyutai-labs/hibiki"},"payload":{"action":"started"},"public":true,"created_at":"2025-02-06T16:37:43Z","org":{"id":151010778,"login":"kyutai-labs","gravatar_id":"","url":"https://api.github.com/orgs/kyutai-labs","avatar_url":"https://avatars.githubusercontent.com/u/151010778?"}},{"id":"46306376612","type":"IssuesEvent","actor":{"id":50035229,"login":"Leizhenpeng","display_login":"Leizhenpeng","gravatar_id":"","url":"https://api.github.com/users/Leizhenpeng","avatar_url":"https://avatars.githubusercontent.com/u/50035229?"},"repo":{"id":612344730,"name":"ChatGPTNextWeb/NextChat","url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094","repository_url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat","labels_url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/labels{/name}","comments_url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/comments","events_url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/events","html_url":"https://github.com/ChatGPTNextWeb/NextChat/issues/6094","id":2810812678,"node_id":"I_kwDOJH-jms6niZkG","number":6094,"title":"[Bug] 网页版突然自动刷新、并丢失所有本地记录","user":{"login":"GesiIvy128","id":16591673,"node_id":"MDQ6VXNlcjE2NTkxNjcz","avatar_url":"https://avatars.githubusercontent.com/u/16591673?v=4","gravatar_id":"","url":"https://api.github.com/users/GesiIvy128","html_url":"https://github.com/GesiIvy128","followers_url":"https://api.github.com/users/GesiIvy128/followers","following_url":"https://api.github.com/users/GesiIvy128/following{/other_user}","gists_url":"https://api.github.com/users/GesiIvy128/gists{/gist_id}","starred_url":"https://api.github.com/users/GesiIvy128/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/GesiIvy128/subscriptions","organizations_url":"https://api.github.com/users/GesiIvy128/orgs","repos_url":"https://api.github.com/users/GesiIvy128/repos","events_url":"https://api.github.com/users/GesiIvy128/events{/privacy}","received_events_url":"https://api.github.com/users/GesiIvy128/received_events","type":"User","user_view_type":"public","site_admin":false},"labels":[{"id":5250811086,"node_id":"LA_kwDOJH-jms8AAAABOPkEzg","url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/labels/bug","name":"bug","color":"d73a4a","default":true,"description":"Something isn\'t working"}],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2025-01-25T06:51:34Z","updated_at":"2025-02-06T16:37:42Z","closed_at":"2025-02-06T16:37:42Z","author_association":"NONE","sub_issues_summary":{"total":0,"completed":0,"percent_completed":0},"active_lock_reason":null,"body":"### 📦 Deployment Method\\n\\nVercel\\n\\n### 📌 Version\\n\\n2.15.8\\n\\n### 💻 Operating System\\n\\nWindows\\n\\n### 📌 System Version\\n\\nWin11\\n\\n### 🌐 Browser\\n\\nChrome\\n\\n### 📌 Browser Version\\n\\n132.0.6834.110\\n\\n### 🐛 Bug Description\\n\\n昨晚在使用时突然自动刷新，然后我就丢失了自己所有的本地记录，之前的聊天记录全部消失。我查看了Chrome Default目录下的IndexedDB文件夹，发现全被覆盖成了新的（也就是聊天记录被覆盖），log文件大小从数个Mb直接降为了仅有几Kb.\\n\\n### 📷 Recurrence Steps\\n\\n我不知道如何复现，因为这个问题是突然出现的\\n\\n### 🚦 Expected Behavior\\n\\n如果可能的话，能否告知我如何找回那些聊天记录。我用数据恢复软件可以找回Chrome的旧IndexedDB文件，但我不知道如何还原。\\n\\n### 📝 Additional Information\\n\\n_No response_","reactions":{"url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/timeline","perform ...

# %%
r.json()
# Out:
# [{'id': '46306376622',
#   'type': 'WatchEvent',
#   'actor': {'id': 81527587,
#    'login': 'denizkarhan',
#    'display_login': 'denizkarhan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/denizkarhan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81527587?'},
#   'repo': {'id': 926978798,
#    'name': 'kyutai-labs/hibiki',
#    'url': 'https://api.github.com/repos/kyutai-labs/hibiki'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 151010778,
#    'login': 'kyutai-labs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kyutai-labs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151010778?'}},
#  {'id': '46306376612',
#   'type': 'IssuesEvent',
#   'actor': {'id': 50035229,
#    'login': 'Leizhenpeng',
#    'display_login': 'Leizhenpeng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leizhenpeng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50035229?'},
#   'repo': {'id': 612344730,
#    'name': 'ChatGPTNextWeb/NextChat',
#    'url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094',
#     'repository_url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat',
#     'labels_url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/comments',
#     'events_url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/events',
#     'html_url': 'https://github.com/ChatGPTNextWeb/NextChat/issues/6094',
#     'id': 2810812678,
#     'node_id': 'I_kwDOJH-jms6niZkG',
#     'number': 6094,
#     'title': '[Bug] 网页版突然自动刷新、并丢失所有本地记录',
#     'user': {'login': 'GesiIvy128',
#      'id': 16591673,
#      'node_id': 'MDQ6VXNlcjE2NTkxNjcz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16591673?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GesiIvy128',
#      'html_url': 'https://github.com/GesiIvy128',
#      'followers_url': 'https://api.github.com/users/GesiIvy128/followers',
#      'following_url': 'https://api.github.com/users/GesiIvy128/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GesiIvy128/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GesiIvy128/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GesiIvy128/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GesiIvy128/orgs',
#      'repos_url': 'https://api.github.com/users/GesiIvy128/repos',
#      'events_url': 'https://api.github.com/users/GesiIvy128/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GesiIvy128/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 5250811086,
#       'node_id': 'LA_kwDOJH-jms8AAAABOPkEzg',
#       'url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2025-01-25T06:51:34Z',
#     'updated_at': '2025-02-06T16:37:42Z',
#     'closed_at': '2025-02-06T16:37:42Z',
#     'author_association': 'NONE',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'body': '### 📦 Deployment Method\n\nVercel\n\n### 📌 Version\n\n2.15.8\n\n### 💻 Operating System\n\nWindows\n\n### 📌 System Version\n\nWin11\n\n### 🌐 Browser\n\nChrome\n\n### 📌 Browser Version\n\n132.0.6834.110\n\n### 🐛 Bug Description\n\n昨晚在使用时突然自动刷新，然后我就丢失了自己所有的本地记录，之前的聊天记录全部消失。我查看了Chrome Default目录下的IndexedDB文件夹，发现全被覆盖成了新的（也就是聊天记录被覆盖），log文件大小从数个Mb直接降为了仅有几Kb.\n\n### 📷 Recurrence Steps\n\n我不知道如何复现，因为这个问题是突然出现的\n\n### 🚦 Expected Behavior\n\n如果可能的话，能否告知我如何找回那些聊天记录。我用数据恢复软件可以找回Chrome的旧IndexedDB文件，但我不知道如何还原。\n\n### 📝 Additional Information\n\n_No response_',
#     'reactions': {'url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ChatGPTNextWeb/NextChat/issues/6094/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 153288546,
#    'login': 'ChatGPTNextWeb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ChatGPTNextWeb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153288546?'}},
#  {'id': '46306376548',
#   'type': 'PushEvent',
#   'actor': {'id': 94220066,
#    'login': 'detos1998',
#    'display_login': 'detos1998',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/detos1998',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94220066?'},
#   'repo': {'id': 928249110,
#    'name': 'detos1998/License',
#    'url': 'https://api.github.com/repos/detos1998/License'},
#   'payload': {'repository_id': 928249110,
#    'push_id': 22516643152,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0b000188914105b09c0f65d9c7954496f0092d0a',
#    'before': '48e26f3a60db92100a95c0143d0e2f874cee79af',
#    'commits': [{'sha': '0b000188914105b09c0f65d9c7954496f0092d0a',
#      'author': {'email': '94220066+detos1998@users.noreply.github.com',
#       'name': 'detos1998'},
#      'message': 'Update asu.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/detos1998/License/commits/0b000188914105b09c0f65d9c7954496f0092d0a'}]},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z'},
#  {'id': '46306376529',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 19409,
#    'login': 'devongovett',
#    'display_login': 'devongovett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devongovett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19409?'},
#   'repo': {'id': 208362715,
#    'name': 'adobe/react-spectrum',
#    'url': 'https://api.github.com/repos/adobe/react-spectrum'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/comments/1945060501',
#     'pull_request_review_id': 2599260229,
#     'id': 1945060501,
#     'node_id': 'PRRC_kwDODGtc285z70SV',
#     'diff_hunk': "@@ -201,6 +201,18 @@ export function UNSTABLE_useAutocomplete(props: AriaAutocompleteOptions, state:\n         // But what about wrapped grids where ArrowLeft and ArrowRight should navigate left/right\n         clearVirtualFocus();\n         break;\n+      case 'Tab':\n+        // Moving forward will always go into the collection which will handle Tab itself, prevent the browser's default tab behavior so both don't happen",
#     'path': 'packages/@react-aria/autocomplete/src/useAutocomplete.ts',
#     'commit_id': '0e943c3395e0240498d916ffb4d0367cd257926b',
#     'original_commit_id': '0e943c3395e0240498d916ffb4d0367cd257926b',
#     'user': {'login': 'devongovett',
#      'id': 19409,
#      'node_id': 'MDQ6VXNlcjE5NDA5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19409?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/devongovett',
#      'html_url': 'https://github.com/devongovett',
#      'followers_url': 'https://api.github.com/users/devongovett/followers',
#      'following_url': 'https://api.github.com/users/devongovett/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/devongovett/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/devongovett/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/devongovett/subscriptions',
#      'organizations_url': 'https://api.github.com/users/devongovett/orgs',
#      'repos_url': 'https://api.github.com/users/devongovett/repos',
#      'events_url': 'https://api.github.com/users/devongovett/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/devongovett/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'oh btw, looks like Daniel also already found this in his PR: https://github.com/adobe/react-spectrum/pull/7561/files#diff-438043cb2e3951363a3350ad94e45c05c063a3cea6dcb4c360e8a01848b2fcc5R193',
#     'created_at': '2025-02-06T16:37:41Z',
#     'updated_at': '2025-02-06T16:37:42Z',
#     'html_url': 'https://github.com/adobe/react-spectrum/pull/7724#discussion_r1945060501',
#     'pull_request_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/comments/1945060501'},
#      'html': {'href': 'https://github.com/adobe/react-spectrum/pull/7724#discussion_r1945060501'},
#      'pull_request': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724'}},
#     'reactions': {'url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/comments/1945060501/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 205,
#     'original_line': 205,
#     'side': 'RIGHT',
#     'in_reply_to_id': 1943213271,
#     'original_position': 5,
#     'position': 5,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724',
#     'id': 2316624679,
#     'node_id': 'PR_kwDODGtc286KFOMn',
#     'html_url': 'https://github.com/adobe/react-spectrum/pull/7724',
#     'diff_url': 'https://github.com/adobe/react-spectrum/pull/7724.diff',
#     'patch_url': 'https://github.com/adobe/react-spectrum/pull/7724.patch',
#     'issue_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/7724',
#     'number': 7724,
#     'state': 'open',
#     'locked': False,
#     'title': "fix: Autocomplete 'tab' key forwarding",
#     'user': {'login': 'snowystinger',
#      'id': 698229,
#      'node_id': 'MDQ6VXNlcjY5ODIyOQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/698229?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/snowystinger',
#      'html_url': 'https://github.com/snowystinger',
#      'followers_url': 'https://api.github.com/users/snowystinger/followers',
#      'following_url': 'https://api.github.com/users/snowystinger/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/snowystinger/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/snowystinger/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/snowystinger/subscriptions',
#      'organizations_url': 'https://api.github.com/users/snowystinger/orgs',
#      'repos_url': 'https://api.github.com/users/snowystinger/repos',
#      'events_url': 'https://api.github.com/users/snowystinger/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/snowystinger/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Closes https://github.com/adobe/react-spectrum/issues/7619\r\n\r\nFirst bug of https://github.com/adobe/react-spectrum/issues/7619#issuecomment-2626073056\r\n\r\n## ✅ Pull Request Checklist:\r\n\r\n- [ ] Included link to corresponding [React Spectrum GitHub Issue](https://github.com/adobe/react-spectrum/issues).\r\n- [ ] Added/updated unit tests and storybook for this change (for new code or code which already has tests).\r\n- [ ] Filled out test instructions.\r\n- [ ] Updated documentation (if it already exists for this component).\r\n- [ ] Looked at the Accessibility Practices for this feature - [Aria Practices](https://www.w3.org/WAI/ARIA/apg/)\r\n\r\n## 📝 Test Instructions:\r\n\r\n<!--- Include instructions to test this pull request -->\r\n\r\n## 🧢 Your Project:\r\n\r\n<!--- Company/project for pull request -->\r\n',
#     'created_at': '2025-02-05T04:20:50Z',
#     'updated_at': '2025-02-06T16:37:41Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'e80f4301ce7a1f00c3881ceda4dfaa1666dfa1b5',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724/commits',
#     'review_comments_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724/comments',
#     'review_comment_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/7724/comments',
#     'statuses_url': 'https://api.github.com/repos/adobe/react-spectrum/statuses/0e943c3395e0240498d916ffb4d0367cd257926b',
#     'head': {'label': 'adobe:fix-autocomplete-focus-management',
#      'ref': 'fix-autocomplete-focus-management',
#      'sha': '0e943c3395e0240498d916ffb4d0367cd257926b',
#      'user': {'login': 'adobe',
#       'id': 476009,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NjAwOQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/476009?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/adobe',
#       'html_url': 'https://github.com/adobe',
#       'followers_url': 'https://api.github.com/users/adobe/followers',
#       'following_url': 'https://api.github.com/users/adobe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/adobe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/adobe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/adobe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/adobe/orgs',
#       'repos_url': 'https://api.github.com/users/adobe/repos',
#       'events_url': 'https://api.github.com/users/adobe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/adobe/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 208362715,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDgzNjI3MTU=',
#       'name': 'react-spectrum',
#       'full_name': 'adobe/react-spectrum',
#       'private': False,
#       'owner': {'login': 'adobe',
#        'id': 476009,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NjAwOQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/476009?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/adobe',
#        'html_url': 'https://github.com/adobe',
#        'followers_url': 'https://api.github.com/users/adobe/followers',
#        'following_url': 'https://api.github.com/users/adobe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/adobe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/adobe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/adobe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/adobe/orgs',
#        'repos_url': 'https://api.github.com/users/adobe/repos',
#        'events_url': 'https://api.github.com/users/adobe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/adobe/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/adobe/react-spectrum',
#       'description': 'A collection of libraries and tools that help you build adaptive, accessible, and robust user experiences.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/adobe/react-spectrum',
#       'forks_url': 'https://api.github.com/repos/adobe/react-spectrum/forks',
#       'keys_url': 'https://api.github.com/repos/adobe/react-spectrum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/adobe/react-spectrum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/adobe/react-spectrum/teams',
#       'hooks_url': 'https://api.github.com/repos/adobe/react-spectrum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/adobe/react-spectrum/events',
#       'assignees_url': 'https://api.github.com/repos/adobe/react-spectrum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/adobe/react-spectrum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/adobe/react-spectrum/tags',
#       'blobs_url': 'https://api.github.com/repos/adobe/react-spectrum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/adobe/react-spectrum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/adobe/react-spectrum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/adobe/react-spectrum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/adobe/react-spectrum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/adobe/react-spectrum/languages',
#       'stargazers_url': 'https://api.github.com/repos/adobe/react-spectrum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/adobe/react-spectrum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/adobe/react-spectrum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/adobe/react-spectrum/subscription',
#       'commits_url': 'https://api.github.com/repos/adobe/react-spectrum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/adobe/react-spectrum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/adobe/react-spectrum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/adobe/react-spectrum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/adobe/react-spectrum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/adobe/react-spectrum/merges',
#       'archive_url': 'https://api.github.com/repos/adobe/react-spectrum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/adobe/react-spectrum/downloads',
#       'issues_url': 'https://api.github.com/repos/adobe/react-spectrum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/adobe/react-spectrum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/adobe/react-spectrum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/adobe/react-spectrum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/adobe/react-spectrum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/adobe/react-spectrum/deployments',
#       'created_at': '2019-09-13T23:32:51Z',
#       'updated_at': '2025-02-06T16:00:43Z',
#       'pushed_at': '2025-02-06T15:50:40Z',
#       'git_url': 'git://github.com/adobe/react-spectrum.git',
#       'ssh_url': 'git@github.com:adobe/react-spectrum.git',
#       'clone_url': 'https://github.com/adobe/react-spectrum.git',
#       'svn_url': 'https://github.com/adobe/react-spectrum',
#       'homepage': 'https://react-spectrum.adobe.com',
#       'size': 143019,
#       'stargazers_count': 13410,
#       'watchers_count': 13410,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 1167,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 735,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['accessibility',
#        'design-systems',
#        'react',
#        'react-components',
#        'ui-components',
#        'wai-aria'],
#       'visibility': 'public',
#       'forks': 1167,
#       'open_issues': 735,
#       'watchers': 13410,
#       'default_branch': 'main'}},
#     'base': {'label': 'adobe:main',
#      'ref': 'main',
#      'sha': '2788d8afdbdbafe0e8d928710c5f458102047348',
#      'user': {'login': 'adobe',
#       'id': 476009,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NjAwOQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/476009?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/adobe',
#       'html_url': 'https://github.com/adobe',
#       'followers_url': 'https://api.github.com/users/adobe/followers',
#       'following_url': 'https://api.github.com/users/adobe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/adobe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/adobe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/adobe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/adobe/orgs',
#       'repos_url': 'https://api.github.com/users/adobe/repos',
#       'events_url': 'https://api.github.com/users/adobe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/adobe/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 208362715,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDgzNjI3MTU=',
#       'name': 'react-spectrum',
#       'full_name': 'adobe/react-spectrum',
#       'private': False,
#       'owner': {'login': 'adobe',
#        'id': 476009,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3NjAwOQ==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/476009?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/adobe',
#        'html_url': 'https://github.com/adobe',
#        'followers_url': 'https://api.github.com/users/adobe/followers',
#        'following_url': 'https://api.github.com/users/adobe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/adobe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/adobe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/adobe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/adobe/orgs',
#        'repos_url': 'https://api.github.com/users/adobe/repos',
#        'events_url': 'https://api.github.com/users/adobe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/adobe/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/adobe/react-spectrum',
#       'description': 'A collection of libraries and tools that help you build adaptive, accessible, and robust user experiences.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/adobe/react-spectrum',
#       'forks_url': 'https://api.github.com/repos/adobe/react-spectrum/forks',
#       'keys_url': 'https://api.github.com/repos/adobe/react-spectrum/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/adobe/react-spectrum/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/adobe/react-spectrum/teams',
#       'hooks_url': 'https://api.github.com/repos/adobe/react-spectrum/hooks',
#       'issue_events_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/adobe/react-spectrum/events',
#       'assignees_url': 'https://api.github.com/repos/adobe/react-spectrum/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/adobe/react-spectrum/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/adobe/react-spectrum/tags',
#       'blobs_url': 'https://api.github.com/repos/adobe/react-spectrum/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/adobe/react-spectrum/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/adobe/react-spectrum/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/adobe/react-spectrum/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/adobe/react-spectrum/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/adobe/react-spectrum/languages',
#       'stargazers_url': 'https://api.github.com/repos/adobe/react-spectrum/stargazers',
#       'contributors_url': 'https://api.github.com/repos/adobe/react-spectrum/contributors',
#       'subscribers_url': 'https://api.github.com/repos/adobe/react-spectrum/subscribers',
#       'subscription_url': 'https://api.github.com/repos/adobe/react-spectrum/subscription',
#       'commits_url': 'https://api.github.com/repos/adobe/react-spectrum/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/adobe/react-spectrum/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/adobe/react-spectrum/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/adobe/react-spectrum/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/adobe/react-spectrum/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/adobe/react-spectrum/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/adobe/react-spectrum/merges',
#       'archive_url': 'https://api.github.com/repos/adobe/react-spectrum/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/adobe/react-spectrum/downloads',
#       'issues_url': 'https://api.github.com/repos/adobe/react-spectrum/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/adobe/react-spectrum/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/adobe/react-spectrum/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/adobe/react-spectrum/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/adobe/react-spectrum/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/adobe/react-spectrum/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/adobe/react-spectrum/deployments',
#       'created_at': '2019-09-13T23:32:51Z',
#       'updated_at': '2025-02-06T16:00:43Z',
#       'pushed_at': '2025-02-06T15:50:40Z',
#       'git_url': 'git://github.com/adobe/react-spectrum.git',
#       'ssh_url': 'git@github.com:adobe/react-spectrum.git',
#       'clone_url': 'https://github.com/adobe/react-spectrum.git',
#       'svn_url': 'https://github.com/adobe/react-spectrum',
#       'homepage': 'https://react-spectrum.adobe.com',
#       'size': 143019,
#       'stargazers_count': 13410,
#       'watchers_count': 13410,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 1167,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 735,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['accessibility',
#        'design-systems',
#        'react',
#        'react-components',
#        'ui-components',
#        'wai-aria'],
#       'visibility': 'public',
#       'forks': 1167,
#       'open_issues': 735,
#       'watchers': 13410,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724'},
#      'html': {'href': 'https://github.com/adobe/react-spectrum/pull/7724'},
#      'issue': {'href': 'https://api.github.com/repos/adobe/react-spectrum/issues/7724'},
#      'comments': {'href': 'https://api.github.com/repos/adobe/react-spectrum/issues/7724/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/adobe/react-spectrum/pulls/7724/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/adobe/react-spectrum/statuses/0e943c3395e0240498d916ffb4d0367cd257926b'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2025-02-06T16:37:41Z',
#   'org': {'id': 476009,
#    'login': 'adobe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adobe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/476009?'}},
#  {'id': '46306376546',
#   'type': 'PublicEvent',
#   'actor': {'id': 138811542,
#    'login': 'NicolasCalina',
#    'display_login': 'NicolasCalina',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NicolasCalina',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138811542?'},
#   'repo': {'id': 899918413,
#    'name': 'NicolasCalina/Banking-System',
#    'url': 'https://api.github.com/repos/NicolasCalina/Banking-System'},
#   'payload': {},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z'},
#  {'id': '46306376549',
#   'type': 'DeleteEvent',
#   'actor': {'id': 58703134,
#    'login': 'cw-owasp',
#    'display_login': 'cw-owasp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cw-owasp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58703134?'},
#   'repo': {'id': 321690453,
#    'name': 'OWASP/cornucopia',
#    'url': 'https://api.github.com/repos/OWASP/cornucopia'},
#   'payload': {'ref': 'cw-owasp-patch-4',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 155815,
#    'login': 'OWASP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OWASP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/155815?'}},
#  {'id': '46306376516',
#   'type': 'CreateEvent',
#   'actor': {'id': 937946,
#    'login': 'praveen-pk',
#    'display_login': 'praveen-pk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/praveen-pk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/937946?'},
#   'repo': {'id': 309523170,
#    'name': 'praveen-pk/libvirt',
#    'url': 'https://api.github.com/repos/praveen-pk/libvirt'},
#   'payload': {'ref': 'upstream/sev_snp',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Read-only mirror. Please submit merge requests / issues to https://gitlab.com/libvirt/libvirt',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z'},
#  {'id': '46306376495',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 115510880,
#    'login': 'bernardodemarco',
#    'display_login': 'bernardodemarco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bernardodemarco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115510880?'},
#   'repo': {'id': 9759448,
#    'name': 'apache/cloudstack',
#    'url': 'https://api.github.com/repos/apache/cloudstack'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/apache/cloudstack/issues/10338',
#     'repository_url': 'https://api.github.com/repos/apache/cloudstack',
#     'labels_url': 'https://api.github.com/repos/apache/cloudstack/issues/10338/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/apache/cloudstack/issues/10338/comments',
#     'events_url': 'https://api.github.com/repos/apache/cloudstack/issues/10338/events',
#     'html_url': 'https://github.com/apache/cloudstack/pull/10338',
#     'id': 2835707345,
#     'node_id': 'PR_kwDOAJTq2M6KSZEe',
#     'number': 10338,
#     'title': 'Make isAccountAllowedToCreateOfferingsWithTags API id parameter required',
#     'user': {'login': 'erik-bock-silva',
#      'id': 188061026,
#      'node_id': 'U_kgDOCzWVYg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/188061026?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/erik-bock-silva',
#      'html_url': 'https://github.com/erik-bock-silva',
#      'followers_url': 'https://api.github.com/users/erik-bock-silva/followers',
#      'following_url': 'https://api.github.com/users/erik-bock-silva/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/erik-bock-silva/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/erik-bock-silva/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/erik-bock-silva/subscriptions',
#      'organizations_url': 'https://api.github.com/users/erik-bock-silva/orgs',
#      'repos_url': 'https://api.github.com/users/erik-bock-silva/repos',
#      'events_url': 'https://api.github.com/users/erik-bock-silva/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/erik-bock-silva/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 584073853,
#       'node_id': 'MDU6TGFiZWw1ODQwNzM4NTM=',
#       'url': 'https://api.github.com/repos/apache/cloudstack/labels/component:api',
#       'name': 'component:api',
#       'color': '1DB401',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/apache/cloudstack/milestones/36',
#      'html_url': 'https://github.com/apache/cloudstack/milestone/36',
#      'labels_url': 'https://api.github.com/repos/apache/cloudstack/milestones/36/labels',
#      'id': 11531641,
#      'node_id': 'MI_kwDOAJTq2M4Ar_V5',
#      'number': 36,
#      'title': '4.20.1',
#      'description': '',
#      'creator': {'login': 'DaanHoogland',
#       'id': 2486961,
#       'node_id': 'MDQ6VXNlcjI0ODY5NjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2486961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DaanHoogland',
#       'html_url': 'https://github.com/DaanHoogland',
#       'followers_url': 'https://api.github.com/users/DaanHoogland/followers',
#       'following_url': 'https://api.github.com/users/DaanHoogland/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DaanHoogland/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DaanHoogland/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DaanHoogland/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DaanHoogland/orgs',
#       'repos_url': 'https://api.github.com/users/DaanHoogland/repos',
#       'events_url': 'https://api.github.com/users/DaanHoogland/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DaanHoogland/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'open_issues': 54,
#      'closed_issues': 47,
#      'state': 'open',
#      'created_at': '2024-09-03T08:11:34Z',
#      'updated_at': '2025-02-06T15:07:14Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 3,
#     'created_at': '2025-02-06T14:33:25Z',
#     'updated_at': '2025-02-06T16:37:41Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/apache/cloudstack/pulls/10338',
#      'html_url': 'https://github.com/apache/cloudstack/pull/10338',
#      'diff_url': 'https://github.com/apache/cloudstack/pull/10338.diff',
#      'patch_url': 'https://github.com/apache/cloudstack/pull/10338.patch',
#      'merged_at': None},
#     'body': '### Description\r\n\r\nThis PR makes the `id` parameter from `isAccountAllowedToCreateOfferingsWithTags` api required to prevent a NullPointerException when trying to execute the command without an `id`.\r\n\r\n### Types of changes\r\n\r\n- [ ] Breaking change (fix or feature that would cause existing functionality to change)\r\n- [ ] New feature (non-breaking change which adds functionality)\r\n- [X] Bug fix (non-breaking change which fixes an issue)\r\n- [ ] Enhancement (improves an existing feature and functionality)\r\n- [ ] Cleanup (Code refactoring and cleanup, that may add test cases)\r\n- [ ] build/CI\r\n- [ ] test (unit or integration test code)\r\n\r\n### Feature/Enhancement Scale or Bug Severity\r\n\r\n#### Bug Severity\r\n\r\n- [ ] BLOCKER\r\n- [ ] Critical\r\n- [ ] Major\r\n- [ ] Minor\r\n- [X] Trivial\r\n\r\n### How Has This Been Tested?\r\n\r\nI\'ve created a test environment with a CloudStack setup. When I tried to execute the command without the `id` parameter, the following exception was thrown:\r\n\r\n```\r\n2025-02-03 15:00:11,909 ERROR [c.c.a.ApiServer] (qtp1507118393-20:[ctx-de956cc8, ctx-37d7a594]) (logid:5e002cf6) unhandled exception executing api command: [Ljava.lang.String;@588ef940 java.lang.NullPointerException: Cannot invoke "java.lang.Long.longValue()" because the return value of "org.apache.cloudstack.api.command.admin.offering.IsAccountAllowedToCreateOfferingsWithTagsCmd.getId()" is null\r\n\tat com.cloud.configuration.ConfigurationManagerImpl.isAccountAllowedToCreateOfferingsWithTags(ConfigurationManagerImpl.java:8076)\r\n\tat java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\r\n\tat java.base/jdk.internal.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:77)\r\n\tat java.base/jdk.internal.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\r\n\tat java.base/java.lang.reflect.Method.invoke(Method.java:569)\r\n\tat org.springframework.aop.support.AopUtils.invokeJoinpointUsingReflection(AopUtils.java:344)\r\n\tat org.springframework.aop.framework.ReflectiveMethodInvocation.invokeJoinpoint(ReflectiveMethodInvocation.java:198)\r\n\tat org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:163)\r\n\tat org.springframework.aop.interceptor.ExposeInvocationInterceptor.invoke(ExposeInvocationInterceptor.java:97)\r\n\tat org.springframework.aop.framework.ReflectiveMethodInvocation.proceed(ReflectiveMethodInvocation.java:186)\r\n\tat org.springframework.aop.framework.JdkDynamicAopProxy.invoke(JdkDynamicAopProxy.java:215)\r\n\tat jdk.proxy3/jdk.proxy3.$Proxy149.isAccountAllowedToCreateOfferingsWithTags(Unknown Source)\r\n\tat org.apache.cloudstack.api.command.admin.offering.IsAccountAllowedToCreateOfferingsWithTagsCmd.execute(IsAccountAllowedToCreateOfferingsWithTagsCmd.java:37)\r\n```\r\n\r\nThen I built and applied the updated packages to my environment. After that, I tried to force the same error to ensure my fix was working. The response shown was now the message: `Missing required parameters:  id`',
#     'reactions': {'url': 'https://api.github.com/repos/apache/cloudstack/issues/10338/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/apache/cloudstack/issues/10338/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/apache/cloudstack/issues/comments/2640363165',
#     'html_url': 'https://github.com/apache/cloudstack/pull/10338#issuecomment-2640363165',
#     'issue_url': 'https://api.github.com/repos/apache/cloudstack/issues/10338',
#     'id': 2640363165,
#     'node_id': 'IC_kwDOAJTq2M6dYL6d',
#     'user': {'login': 'bernardodemarco',
#      'id': 115510880,
#      'node_id': 'U_kgDOBuKOYA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/115510880?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bernardodemarco',
#      'html_url': 'https://github.com/bernardodemarco',
#      'followers_url': 'https://api.github.com/users/bernardodemarco/followers',
#      'following_url': 'https://api.github.com/users/bernardodemarco/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bernardodemarco/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bernardodemarco/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bernardodemarco/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bernardodemarco/orgs',
#      'repos_url': 'https://api.github.com/users/bernardodemarco/repos',
#      'events_url': 'https://api.github.com/users/bernardodemarco/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bernardodemarco/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2025-02-06T16:37:41Z',
#     'updated_at': '2025-02-06T16:37:41Z',
#     'author_association': 'COLLABORATOR',
#     'body': "> If it was impossible to execute the query before without `id`, I am alright with it. Otherwise this is a backwards incompatibility.\r\n\r\n@DaanHoogland, yes, previously, it was impossible to execute the API without an `id`.\r\n\r\nWhen the API's service layer method is executed, the flow tries to retrieve the account with the specified `id` from the DB:\r\nhttps://github.com/apache/cloudstack/blob/2ef16132ee92a51bed093c602a706446bd4cd88c/server/src/main/java/com/cloud/configuration/ConfigurationManagerImpl.java#L8074-L8076\r\n\r\nHowever, the `getAccount` method expects the `accountId` parameter as the `long` primitive: \r\nhttps://github.com/apache/cloudstack/blob/2ef16132ee92a51bed093c602a706446bd4cd88c/server/src/main/java/com/cloud/user/AccountManagerImpl.java#L2488-L2491\r\n\r\nTherefore, when the method is executed specifying `null` as argument, a NPE is thrown. ",
#     'reactions': {'url': 'https://api.github.com/repos/apache/cloudstack/issues/comments/2640363165/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '46306376482',
#   'type': 'IssuesEvent',
#   'actor': {'id': 140399042,
#    'login': 'eldar2o',
#    'display_login': 'eldar2o',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eldar2o',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/140399042?'},
#   'repo': {'id': 928438004,
#    'name': 'eldar2o/eolymp',
#    'url': 'https://api.github.com/repos/eldar2o/eolymp'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1',
#     'repository_url': 'https://api.github.com/repos/eldar2o/eolymp',
#     'labels_url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1/events',
#     'html_url': 'https://github.com/eldar2o/eolymp/issues/1',
#     'id': 2836033541,
#     'node_id': 'I_kwDON1bW9M6pCnAF',
#     'number': 1,
#     'title': '1-Simple Problem',
#     'user': {'login': 'eldar2o',
#      'id': 140399042,
#      'node_id': 'U_kgDOCF5Rwg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/140399042?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eldar2o',
#      'html_url': 'https://github.com/eldar2o',
#      'followers_url': 'https://api.github.com/users/eldar2o/followers',
#      'following_url': 'https://api.github.com/users/eldar2o/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eldar2o/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eldar2o/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eldar2o/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eldar2o/orgs',
#      'repos_url': 'https://api.github.com/users/eldar2o/repos',
#      'events_url': 'https://api.github.com/users/eldar2o/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eldar2o/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'eldar2o',
#      'id': 140399042,
#      'node_id': 'U_kgDOCF5Rwg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/140399042?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eldar2o',
#      'html_url': 'https://github.com/eldar2o',
#      'followers_url': 'https://api.github.com/users/eldar2o/followers',
#      'following_url': 'https://api.github.com/users/eldar2o/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eldar2o/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eldar2o/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eldar2o/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eldar2o/orgs',
#      'repos_url': 'https://api.github.com/users/eldar2o/repos',
#      'events_url': 'https://api.github.com/users/eldar2o/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eldar2o/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'assignees': [{'login': 'eldar2o',
#       'id': 140399042,
#       'node_id': 'U_kgDOCF5Rwg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/140399042?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/eldar2o',
#       'html_url': 'https://github.com/eldar2o',
#       'followers_url': 'https://api.github.com/users/eldar2o/followers',
#       'following_url': 'https://api.github.com/users/eldar2o/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/eldar2o/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/eldar2o/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/eldar2o/subscriptions',
#       'organizations_url': 'https://api.github.com/users/eldar2o/orgs',
#       'repos_url': 'https://api.github.com/users/eldar2o/repos',
#       'events_url': 'https://api.github.com/users/eldar2o/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/eldar2o/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2025-02-06T16:35:47Z',
#     'updated_at': '2025-02-06T16:37:42Z',
#     'closed_at': '2025-02-06T16:37:42Z',
#     'author_association': 'OWNER',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/eldar2o/eolymp/issues/1/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z'},
#  {'id': '46306376440',
#   'type': 'PushEvent',
#   'actor': {'id': 54049465,
#    'login': 'belomaxorka',
#    'display_login': 'belomaxorka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/belomaxorka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54049465?'},
#   'repo': {'id': 22153797,
# ...
#       'git_commits_url': 'https://api.github.com/repos/opaduchak/osf.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/opaduchak/osf.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/opaduchak/osf.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/opaduchak/osf.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/opaduchak/osf.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/opaduchak/osf.io/merges',
#       'archive_url': 'https://api.github.com/repos/opaduchak/osf.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/opaduchak/osf.io/downloads',
#       'issues_url': 'https://api.github.com/repos/opaduchak/osf.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/opaduchak/osf.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/opaduchak/osf.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/opaduchak/osf.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/opaduchak/osf.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/opaduchak/osf.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/opaduchak/osf.io/deployments',
#       'created_at': '2024-01-30T14:05:41Z',
#       'updated_at': '2024-08-01T09:24:41Z',
#       'pushed_at': '2025-02-06T13:16:06Z',
#       'git_url': 'git://github.com/opaduchak/osf.io.git',
#       'ssh_url': 'git@github.com:opaduchak/osf.io.git',
#       'clone_url': 'https://github.com/opaduchak/osf.io.git',
#       'svn_url': 'https://github.com/opaduchak/osf.io',
#       'homepage': 'https://osf.io',
#       'size': 199338,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     'base': {'label': 'CenterForOpenScience:feature/b-and-i-25-01',
#      'ref': 'feature/b-and-i-25-01',
#      'sha': 'd370e2b3e6367969f7d877dcfb5d425c5a115391',
#      'user': {'login': 'CenterForOpenScience',
#       'id': 3344584,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNDQ1ODQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3344584?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/CenterForOpenScience',
#       'html_url': 'https://github.com/CenterForOpenScience',
#       'followers_url': 'https://api.github.com/users/CenterForOpenScience/followers',
#       'following_url': 'https://api.github.com/users/CenterForOpenScience/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/CenterForOpenScience/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/CenterForOpenScience/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/CenterForOpenScience/subscriptions',
#       'organizations_url': 'https://api.github.com/users/CenterForOpenScience/orgs',
#       'repos_url': 'https://api.github.com/users/CenterForOpenScience/repos',
#       'events_url': 'https://api.github.com/users/CenterForOpenScience/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/CenterForOpenScience/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 10199599,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDE5OTU5OQ==',
#       'name': 'osf.io',
#       'full_name': 'CenterForOpenScience/osf.io',
#       'private': False,
#       'owner': {'login': 'CenterForOpenScience',
#        'id': 3344584,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzNDQ1ODQ=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/3344584?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/CenterForOpenScience',
#        'html_url': 'https://github.com/CenterForOpenScience',
#        'followers_url': 'https://api.github.com/users/CenterForOpenScience/followers',
#        'following_url': 'https://api.github.com/users/CenterForOpenScience/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/CenterForOpenScience/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/CenterForOpenScience/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/CenterForOpenScience/subscriptions',
#        'organizations_url': 'https://api.github.com/users/CenterForOpenScience/orgs',
#        'repos_url': 'https://api.github.com/users/CenterForOpenScience/repos',
#        'events_url': 'https://api.github.com/users/CenterForOpenScience/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/CenterForOpenScience/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/CenterForOpenScience/osf.io',
#       'description': 'Facilitating Open Science',
#       'fork': False,
#       'url': 'https://api.github.com/repos/CenterForOpenScience/osf.io',
#       'forks_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/forks',
#       'keys_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/teams',
#       'hooks_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/events',
#       'assignees_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/tags',
#       'blobs_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/subscription',
#       'commits_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/merges',
#       'archive_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/downloads',
#       'issues_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/CenterForOpenScience/osf.io/deployments',
#       'created_at': '2013-05-21T15:53:37Z',
#       'updated_at': '2025-02-05T22:18:36Z',
#       'pushed_at': '2025-02-06T03:05:20Z',
#       'git_url': 'git://github.com/CenterForOpenScience/osf.io.git',
#       'ssh_url': 'git@github.com:CenterForOpenScience/osf.io.git',
#       'clone_url': 'https://github.com/CenterForOpenScience/osf.io.git',
#       'svn_url': 'https://github.com/CenterForOpenScience/osf.io',
#       'homepage': 'https://osf.io',
#       'size': 203574,
#       'stargazers_count': 682,
#       'watchers_count': 682,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 336,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 181,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['django',
#        'django-rest-framework',
#        'javascript',
#        'openscience',
#        'python',
#        'science'],
#       'visibility': 'public',
#       'forks': 336,
#       'open_issues': 181,
#       'watchers': 682,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/pulls/10963'},
#      'html': {'href': 'https://github.com/CenterForOpenScience/osf.io/pull/10963'},
#      'issue': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/issues/10963'},
#      'comments': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/issues/10963/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/pulls/10963/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/pulls/10963/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/CenterForOpenScience/osf.io/statuses/c98bd2621cb6c2e910875985d85f8a9c23635540'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'brianjgeiger',
#      'id': 6599111,
#      'node_id': 'MDQ6VXNlcjY1OTkxMTE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6599111?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/brianjgeiger',
#      'html_url': 'https://github.com/brianjgeiger',
#      'followers_url': 'https://api.github.com/users/brianjgeiger/followers',
#      'following_url': 'https://api.github.com/users/brianjgeiger/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/brianjgeiger/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/brianjgeiger/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/brianjgeiger/subscriptions',
#      'organizations_url': 'https://api.github.com/users/brianjgeiger/orgs',
#      'repos_url': 'https://api.github.com/users/brianjgeiger/repos',
#      'events_url': 'https://api.github.com/users/brianjgeiger/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/brianjgeiger/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 1,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 3344584,
#    'login': 'CenterForOpenScience',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CenterForOpenScience',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3344584?'}},
#  {'id': '46306376235',
#   'type': 'PushEvent',
#   'actor': {'id': 42103892,
#    'login': 'ShaokunAn',
#    'display_login': 'ShaokunAn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShaokunAn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42103892?'},
#   'repo': {'id': 926146414,
#    'name': 'ShaokunAn/scCausalVI',
#    'url': 'https://api.github.com/repos/ShaokunAn/scCausalVI'},
#   'payload': {'repository_id': 926146414,
#    'push_id': 22516643007,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'b74ce21edfc38baf68417de675ba366ab497ca4a',
#    'before': 'b8e2519af89140bf76764acb8de1b40ca94aa178',
#    'commits': [{'sha': '1009b672377c0c987c780deedfe776f2e2c7cf43',
#      'author': {'email': 'shaokunan1@gmail.com', 'name': 'sa3520'},
#      'message': 'add biorxiv reference',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ShaokunAn/scCausalVI/commits/1009b672377c0c987c780deedfe776f2e2c7cf43'},
#     {'sha': 'b74ce21edfc38baf68417de675ba366ab497ca4a',
#      'author': {'email': 'shaokunan1@gmail.com', 'name': 'sa3520'},
#      'message': 'update version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ShaokunAn/scCausalVI/commits/b74ce21edfc38baf68417de675ba366ab497ca4a'}]},
#   'public': True,
#   'created_at': '2025-02-06T16:37:42Z'},
#  {'id': '46306376251',
#   'type': 'CreateEvent',
#   'actor': {'id': 143424287,
#    'login': 'xf4isal',
#    'display_login': 'xf4isal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xf4isal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/143424287?'},
#   'repo': {'id': 928439035,
#    'name': 'xf4isal/Bwat-minta-maaf',
#    'url': 'https://api.github.com/repos/xf4isal/Bwat-minta-maaf'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z'},
#  {'id': '46306376247',
#   'type': 'DeleteEvent',
#   'actor': {'id': 11840575,
#    'login': 'jusdino',
#    'display_login': 'jusdino',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jusdino',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11840575?'},
#   'repo': {'id': 807833402,
#    'name': 'InspiringApps/JCC-CompactConnect',
#    'url': 'https://api.github.com/repos/InspiringApps/JCC-CompactConnect'},
#   'payload': {'ref': 'feat/reinvite-staff-user',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-02-06T16:37:43Z',
#   'org': {'id': 505800,
#    'login': 'InspiringApps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/InspiringApps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/505800?'}}]

# %%
r = requests.get('https://api.github.com/versions')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ### Headers

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
r = requests.get('https://api.github.com/events', headers=headers)

# %%
r = requests.get('https://api.github.com/users/judinizz')

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/users/judinizz'

# %%
r.json()['node_id']
# Out:
# 'U_kgDOCQ1oUw'

# %%
r.json()['name']
# Out:
# 'ju'

# %%
r.json()['public_repos']
# Out:
# 5

# %% [markdown]
# ### Linguagens

# %%
api_base_url = 'https://api.github.com/'
owner = 'amzn'
url = f'{api_base_url}users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
r = requests.get(url, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
len(r.json())
# Out:
# 30

# %%
r2 = requests.get(url, params = {"sort":"name"}, headers = headers)

# %%
r2.url
# Out:
# 'https://api.github.com/users/amzn/repos?sort=name'

# %% [markdown]
# ### Token API

# %%
from config import api_token
api_token = api_token
headers = {
    'Authorization': f'Bearer {api_token}',
    'Accept': 'application/vnd.github.v3+json',
    'X-GitHub-Api-Version': '2022-11-28'
}


api_base_url = 'https://api.github.com/'
owner = 'amzn'
url = f'{api_base_url}users/{owner}/repos'

# %%
repos_list = []

for page_num in range(1,6):
    try: 
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %%
len(repos_list[4])
# Out:
# 30

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)

# %% [markdown]
# followers_list = []
# page_num = 1
#
# while True:
#         url_page = f'{url}?page={page_num}'
#         response = requests.get(url_page, headers=headers)
#
#         if len(response.json())==0:
#             print(page)
#             break
#
#         followers_list.append(response.json())
#         page=+1

# %% [markdown]
# ### Transformando os Dados
# Nomes dos Repositórios

# %%
repos_names = []

for page in repos_list:
    for repo in page:
        name = repo['name']
        repos_names.append(name)

# %%
repos_names[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_names)
# Out:
# 150

# %%
repos_languages = []

for page in repos_list:
    for repo in page:
        language = repo['language']
        repos_languages.append(language)

# %%
repos_languages[:10]
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS']

# %%
len(repos_languages)
# Out:
# 150

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_names
dados_amz['language'] = repos_languages

# %%
dados_amz
# Out:
#                         repository_name          language
# 0                               .github              None
# 1               ads-advanced-tools-docs  Jupyter Notebook
# 2           ads-pao-amznjs-gtm-template            Smarty
# 3                            alexa-coho        JavaScript
# 4                   alexa-skills-kit-js              None
# ..                                  ...               ...
# 145  traffic-quality-smart-pixel-loader        TypeScript
# 146                       trans-encoder            Python
# 147          user-satisfaction-modeling            Python
# 148                  workspace-resolver        JavaScript
# 149                              ws-vae            Python
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando o Dataframe

# %%
dados_amz.to_csv('amazon.csv')

# %%
headers = {
    'Authorization': f'Bearer {api_token}',
    'Accept': 'application/vnd.github.v3+json',
    'X-GitHub-Api-Version': '2022-11-28'
}

# %%
def create_repo(headers, name_repo, description, private):
    api_base_url = 'https://api.github.com'
    url = f'{api_base_url}/user/repos'
    data = {
        'name': name_repo,
        'description': description,
        'private': private
    }
    response = requests.post(url, json=data, headers=headers)
    if response.status_code == 201:
        print(f'Repositorio "{name_repo}" criado com sucesso!')
    else:
        print(f'Erro ao criar repositório "{name_repo}"')

# %%
create_repo(headers, 'repo_teste', 'teste', False)
# Out:
# Erro ao criar repositório "repo_teste"

# %%
import base64

# %%
def insert_file_repo(username, name_repo, file_name, headers, message):
    api_base_url = 'https://api.github.com'
    url = f'{api_base_url}/repos/{username}/{name_repo}/contents/{file_name}'

    with open(file_name, 'rb') as file:
        file_content = file.read()

    encoded_content = base64.b64encode(file_content)

    data = {
        'message': message,
        'content': encoded_content.decode('utf-8')
    }

    response = requests.put(url, json=data, headers=headers)
    print(response.status_code)

# %%
insert_file_repo('judinizz', 'repo_teste', 'amazon.csv', headers, 'commit teste')
# Out:
# 422

# %%
repo_fork = 'multilingual-keyphrase-generation'

headers = {
    'Authorization': f'Bearer {api_token}',
    'X-GitHub-Api-Version': '2022-11-28'
}

url_fork = f'{api_base_url}repos/{owner}/{repo_fork}/forks'

# %%
response = requests.post(url_fork, headers=headers)
print(response.status_code)
# Out:
# 202

# %%
url_fork
# Out:
# 'https://api.github.com/repos/amzn/multilingual-keyphrase-generation/forks'
